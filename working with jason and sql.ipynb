# %%
import pandas as pd

# %% [markdown]
# **1. working with jason**

# %%
pd.read_json('xyz.jason') # open local jason file

# %% [markdown]
# open jason file from url

# %%
pd.read_json('abc.json')

# %% [markdown]
# **2. working with sql file**
#
# main explaination in black notebook
