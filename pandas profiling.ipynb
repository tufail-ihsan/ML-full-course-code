# %% [markdown]
# **pandas profiling**

# %%
pip install pandas-profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in d:\anaconda\lib\site-packages (from pandas-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in d:\anaconda\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in d:\anaconda\lib\site-packages (from pandas-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=1.8.1 in d:\anaconda\lib\site-packages (from pandas-profiling) (2.8.2)
# Requirement already satisfied: PyYAML>=5.0.0 in d:\anaconda\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in d:\anaconda\lib\site-packages (from pandas-profiling) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in d:\anaconda\lib\site-packages (from pandas-profiling) (2.1.3)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in d:\anaconda\lib\site-packages (from pandas-profiling) (1.26.4)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.5-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in d:\anaconda\lib\site-packages (from pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.2 in d:\anaconda\lib\site-packages (from pandas-profiling) (4.66.5)
# Requirement already satisfied: seaborn>=0.10.1 in d:\anaconda\lib\site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-2.0.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: attrs>=19.3.0 in d:\anaconda\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in d:\anaconda\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.3)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: Pillow in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\anaconda\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\anaconda\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.8.30)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in d:\anaconda\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.7.0)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.7 MB 409.0 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.5/4.7 MB 409.0 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.5/4.7 MB 409.0 kB/s eta 0:00:11
#    ------ --------------------------------- 0.8/4.7 MB 447.3 kB/s eta 0:00:09
#    -------- ------------------------------- 1.0/4.7 MB 518.8 kB/s eta 0:00:08
#    -------- ------------------------------- 1.0/4.7 MB 518.8 kB/s eta 0:00:08
#    ----------- ---------------------------- 1.3/4.7 MB 564.1 kB/s eta 0:00:07
#    ------------- -------------------------- 1.6/4.7 MB 612.2 kB/s eta 0:00:06
#    --------------- ------------------------ 1.8/4.7 MB 657.8 kB/s eta 0:00:05
#    ----------------- ---------------------- 2.1/4.7 MB 694.8 kB/s eta 0:00:04
#    ------------------- -------------------- 2.4/4.7 MB 733.5 kB/s eta 0:00:04
#    ---------------------- ----------------- 2.6/4.7 MB 758.9 kB/s eta 0:00:03
#    ------------------------ --------------- 2.9/4.7 MB 795.1 kB/s eta 0:00:03
#    -------------------------- ------------- 3.1/4.7 MB 827.7 kB/s eta 0:00:02
#    ---------------------------- ----------- 3.4/4.7 MB 849.5 kB/s eta 0:00:02
#    ------------------------------- -------- 3.7/4.7 MB 875.8 kB/s eta 0:00:02
#    ----------------------------------- ---- 4.2/4.7 MB 939.1 kB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 958.7 kB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 969.6 kB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-2.0.2-py3-none-any.whl (9.6 kB)
# Downloading phik-0.12.5-cp312-cp312-win_amd64.whl (676 kB)
#    ---------------------------------------- 0.0/676.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/676.2 kB ? eta -:--:--
#    ---------------------------------------- 676.2/676.2 kB 2.2 MB/s eta 0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27091 sha256=86018a2a05eb03f5f86c19ca4af18dbd6bebc35a34b3a9a5431e5db61436572c
#   Stored in directory: c:\users\icc ok\appdata\local\pip\cache\wheels\5f\d4\d7\4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, multimethod, joblib, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
# Successfully installed htmlmin-0.1.12 imagehash-4.3.2 joblib-1.1.1 missingno-0.5.2 multimethod-2.0.2 pandas-profiling-3.2.0 phik-0.12.5 tangled-up-in-unicode-0.2.0 visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.5.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.

# %%
from pandas_profiling import ProfileReport

prof = ProfileReport(df)
prof.to_file(output_file="output.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       3 prof = ProfileReport(df)
#       4 prof.to_file(output_file="output.html")
#
# File d:\anaconda\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File d:\anaconda\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File d:\anaconda\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File d:\anaconda\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File d:\anaconda\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File d:\anaconda\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File d:\anaconda\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File d:\anaconda\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File d:\anaconda\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File d:\anaconda\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in d:\anaconda\lib\site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic<3,>=2 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.8.2)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata-profiling)
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting jinja2<3.2,>=3.1.6 (from ydata-profiling)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in d:\anaconda\lib\site-packages (from ydata-profiling) (1.26.4)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: phik<0.13,>=0.12.5 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in d:\anaconda\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in d:\anaconda\lib\site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.14.2)
# Collecting typeguard<5,>=4 (from ydata-profiling)
#   Downloading typeguard-4.5.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: imagehash==4.3.2 in d:\anaconda\lib\site-packages (from ydata-profiling) (4.3.2)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in d:\anaconda\lib\site-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in d:\anaconda\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in d:\anaconda\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in d:\anaconda\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in d:\anaconda\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in d:\anaconda\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Collecting typing-extensions>=4.6.1 (from pydantic<3,>=2->ydata-profiling)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in d:\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in d:\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.3)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-2.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading minify_html-0.18.1-cp312-cp312-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.1 MB 1.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.8/3.1 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.1 MB 1.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.3/3.1 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 1.6/3.1 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 1.6/3.1 MB 1.2 MB/s eta 0:00:02
#    -------------------------- ------------- 2.1/3.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.4/3.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 2.9/3.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.4 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Downloading typeguard-4.5.2-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl (307 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading puremagic-2.2.0-py3-none-any.whl (71 kB)
# Installing collected packages: minify-html, filetype, typing-extensions, PyYAML, puremagic, multimethod, jinja2, dacite, typeguard, wordcloud, visions, ydata-profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 2.0.2
#     Uninstalling multimethod-2.0.2:
#       Successfully uninstalled multimethod-2.0.2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# Successfully installed PyYAML-6.0.3 dacite-1.9.2 filetype-1.2.0 jinja2-3.1.6 minify-html-0.18.1 multimethod-1.12 puremagic-2.2.0 typeguard-4.5.2 typing-extensions-4.15.0 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.

# %%
import pandas as pd

# %%
df=pd.read_csv("matches - matches.csv")

# %%
from ydata_profiling import ProfileReport

prof = ProfileReport(df)
prof.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 18/18 [00:00<00:00, 60.92it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
netflix=pd.read_csv('netflix_titles.csv')

# %%
from ydata_profiling import ProfileReport

prof = ProfileReport(netflix)
prof.to_file("output1.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:05<00:00,  2.04it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
